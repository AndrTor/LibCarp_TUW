# %%
import pandas as pd
import urllib.request

# %%
url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"

# %%
apc_file = "openapc.csv"

# %%
urllib.request.urlretrieve(url, apc_file)
# Out:
# ('openapc.csv', <http.client.HTTPMessage at 0x1a761807a90>)

# %%
apcs = pd.read_csv(apc_file)

# %%
type(apcs)    #typus abfragen: wir haben jetzt ein dataframe / tabellarische Daten / können auch ausgeworfen werden
# Out:
# pandas.core.frame.DataFrame

# %%
apcs.head()
# Out:
#   institution  period     euro                           doi  is_hybrid  \
# 0   FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1   FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2   FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3   FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4   FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
#
#                           publisher       journal_full_title       issn  \
# 0                   Springer Nature  npj Quantum Information  2056-6387
# 1   American Physical Society (APS)        Physical Review X  2160-3308
# 2                   Springer Nature    Nature Communications  2041-1723
# 3  Public Library of Science (PLoS)           PLOS Pathogens  1553-7374
# 4                   Springer Nature            Gut Pathogens  1757-4749
#
#   issn_print issn_electronic                                  license_ref  \
# 0        NaN       2056-6387                                          NaN
# 1        NaN       2160-3308  http://creativecommons.org/licenses/by/3.0/
# 2        NaN       2041-1723                                          NaN
# 3        NaN       1553-7374  http://creativecommons.org/licenses/by/4.0/
# 4        NaN       1757-4749                                          NaN
#
#    indexed_in_crossref        pmid       pmcid  ut  url  doaj
# 0                 True         NaN         NaN NaN  NaN  True
# 1                 True         NaN         NaN NaN  NaN  True
# 2                 True  26577800.0  PMC4673657 NaN  NaN  True
# 3                 True  26544881.0  PMC4636265 NaN  NaN  True
# 4                 True  26483849.0  PMC4610047 NaN  NaN  True

# %%
apcs.shape
# Out:
# (61, 17)

# %%
apcs[["euro", "period", "doi"]]
# Out:
#        euro  period                            doi
# 0   2000.00    2015          10.1038/npjqi.2015.10
# 1   1503.12    2015      10.1103/PhysRevX.5.041008
# 2   2000.00    2015             10.1038/ncomms9498
# 3   2000.00    2015   10.1371/journal.ppat.1005246
# 4   1805.00    2015      10.1186/s13099-015-0075-z
# 5   1191.32    2015   10.1371/journal.pone.0139894
# 6   1236.83    2015   10.1371/journal.pone.0142240
# 7   1499.08    2015       10.3389/fcimb.2015.00067
# 8   1160.25    2015       10.5194/acp-15-6897-2015
# 9   1191.21    2015   10.1371/journal.pone.0140050
# 10  1142.40    2015       10.3389/fpsyg.2015.01137
# 11  1298.29    2015       10.3389/fpsyg.2015.01661
# 12  2000.00    2015       10.3389/fpsyg.2015.01675
# 13  1165.00    2015              10.1038/srep11598
# 14  1386.35    2015              10.1038/srep12681
# 15  2000.00    2015   10.1371/journal.ppat.1004781
# 16   892.50    2015          10.4081/ejh.2015.2516
# 17  1535.87    2015       10.3389/fbioe.2015.00130
# 18   223.93    2015       10.3389/fpsyg.2015.01526
# 19  1178.42    2015   10.1371/journal.pone.0139402
# 20  1285.52    2015       10.3389/fpsyg.2015.01267
# 21  1392.30    2015  10.1088/1367-2630/17/8/083042
# 22  1509.22    2015        10.3389/fevo.2015.00103
# 23  2000.00    2015         10.1127/metz/2015/0641
# 24  1249.50    2015      10.1186/s13570-015-0035-8
# 25  1625.00    2015      10.1186/s13071-015-0924-0
# 26  1800.00    2015      10.1186/s12862-015-0390-5
# 27  1550.33    2015   10.1016/j.ijpddr.2015.03.003
# 28  2000.00    2015       10.3389/fnhum.2015.00551
# 29  2000.00    2015             10.1038/ncomms8606
# ..      ...     ...                            ...
# 31  1410.07    2015            10.1155/2015/304149
# 32  2000.00    2015      10.1186/s12918-015-0183-x
# 33  1785.00    2015                10.3354/cr01302
# 34  1202.03    2015   10.1371/journal.pone.0130117
# 35  1243.27    2015   10.1371/journal.pone.0133118
# 36  1687.00    2015         10.1127/metz/2015/0642
# 37  1687.00    2015         10.1127/metz/2015/0639
# 38   895.15    2015            10.1155/2015/235184
# 39   853.84    2015          10.4236/me.2015.66072
# 40  1904.00    2015       10.3389/fpsyg.2015.00813
# 41   435.46    2015         10.4236/epe.2015.75022
# 42  1150.00    2015          10.3390/toxins7051556
# 43   770.00    2015       10.3389/fpsyg.2015.00714
# 44  1299.92    2015   10.1371/journal.pone.0126224
# 45  2000.00    2015   10.1371/journal.pcbi.1004200
# 46  1202.03    2015   10.1371/journal.pone.0124550
# 47   430.50    2015          10.17645/pag.v3i2.192
# 48  1600.00    2015       10.3389/fnbeh.2015.00096
# 49  1280.00    2015       10.3389/fpsyg.2015.00079
# 50  1513.70    2015   10.1371/journal.pone.0118179
# 51  1904.00    2015       10.3389/fimmu.2015.00108
# 52  1072.55    2015       10.4142/jvs.2015.16.1.57
# 53   981.75    2015       10.5194/amtd-8-2623-2015
# 54  1969.45    2015      10.1186/s12917-015-0351-7
# 55  1130.50    2015     10.5194/nhessd-3-1231-2015
# 56  1731.45    2015      10.1186/s13015-014-0028-y
# 57  1600.00    2015       10.3389/fpsyg.2015.00194
# 58   219.84    2015        10.3389/fevo.2015.00020
# 59  1386.35    2015              10.1038/srep19416
# 60  2000.00    2015            10.1155/2015/569512
#
# [61 rows x 3 columns]

# %%
apcs[apcs.euro >= 2000]
# Out:
#    institution  period    euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.0          10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.0             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.0   10.1371/journal.ppat.1005246      False
# 12   FU Berlin    2015  2000.0       10.3389/fpsyg.2015.01675      False
# 15   FU Berlin    2015  2000.0   10.1371/journal.ppat.1004781      False
# 23   FU Berlin    2015  2000.0         10.1127/metz/2015/0641      False
# 28   FU Berlin    2015  2000.0       10.3389/fnhum.2015.00551      False
# 29   FU Berlin    2015  2000.0             10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.0      10.1186/s12918-015-0183-x      False
# 45   FU Berlin    2015  2000.0   10.1371/journal.pcbi.1004200      False
# 60   FU Berlin    2015  2000.0            10.1155/2015/569512      False
#
#                            publisher               journal_full_title  \
# 0                    Springer Nature          npj Quantum Information
# 2                    Springer Nature            Nature Communications
# 3   Public Library of Science (PLoS)                   PLOS Pathogens
# 12                Frontiers Media SA          Frontiers in Psychology
# 15  Public Library of Science (PLoS)                   PLOS Pathogens
# 23                     Schweizerbart      Meteorologische Zeitschrift
# 28                Frontiers Media SA  Frontiers in Human Neuroscience
# 29                   Springer Nature            Nature Communications
# 32                   Springer Nature              BMC Systems Biology
# 45  Public Library of Science (PLoS)       PLOS Computational Biology
# 60    Hindawi Publishing Corporation        Mediators of Inflammation
#
#          issn issn_print issn_electronic  \
# 0   2056-6387        NaN       2056-6387
# 2   2041-1723        NaN       2041-1723
# 3   1553-7374        NaN       1553-7374
# 12  1664-1078        NaN       1664-1078
# 15  1553-7374        NaN       1553-7374
# 23  0941-2948        NaN             NaN
# 28  1662-5161        NaN       1662-5161
# 29  2041-1723        NaN       2041-1723
# 32  1752-0509        NaN       1752-0509
# 45  1553-7358        NaN       1553-7358
# 60  0962-9351  0962-9351       1466-1861
#
#                                     license_ref  indexed_in_crossref  \
# 0                                           NaN                 True
# 2                                           NaN                 True
# 3   http://creativecommons.org/licenses/by/4.0/                 True
# 12                                          NaN                 True
# 15  http://creativecommons.org/licenses/by/4.0/                 True
# 23                                          NaN                 True
# 28                                          NaN                 True
# 29                                          NaN                 True
# 32                                          NaN                 True
# 45  http://creativecommons.org/licenses/by/4.0/                 True
# 60  http://creativecommons.org/licenses/by/4.0/                 True
#
#           pmid       pmcid  ut  url  doaj
# 0          NaN         NaN NaN  NaN  True
# 2   26577800.0  PMC4673657 NaN  NaN  True
# 3   26544881.0  PMC4636265 NaN  NaN  True
# 12  26583000.0  PMC4628112 NaN  NaN  True
# 15         NaN         NaN NaN  NaN  True
# 23         NaN         NaN NaN  NaN  True
# 28  26500523.0  PMC4599046 NaN  NaN  True
# 29  26216619.0  PMC4525213 NaN  NaN  True
# 32  26201334.0  PMC4511525 NaN  NaN  True
# 45  25927964.0  PMC4423987 NaN  NaN  True
# 60  26770019.0  PMC4681803 NaN  NaN  True

# %%
apcs_filtered = apcs[apcs.euro >= 2000]

# %%
apcs_filtered.shape
# Out:
# (11, 17)

# %%
# %who
# Out:
# URL	 apc_file	 apcs	 apcs_filtered	 pd	 url	 urllib

# %%
# %matplotlib inline

# %%
apcs.euro.hist()
